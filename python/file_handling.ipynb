# %% [markdown]
# file handling

# %%
file = open("liet.txt", "r")
print(file.read())
file.close()
# Out:
# my name is harpreet singh

# %%
file = open("liet.txt", "a")
file.write("\nNew line added.")
file.close()
